# %% [markdown]
# <a href="https://colab.research.google.com/github/syedam1104-stack/ML-AI-Intership-/blob/main/Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text=input("Enter a string: ")

reverse_text=" "
for char in text:
  reverse_text=char+reverse_text

  print(reverse_text)
# Out:
# Enter a string: momo
# m
# om
# mom
# omom

# %%
list=[34, 67, 98, 102, 105, 34, 78]
sorted_list=sorted(list)
second_largest=sorted_list[-2]

print(second_largest)
# Out:
# 102

# %%
tasks = []

def add_task():
    task = input("Enter task: ")
    tasks.append(task)
    print("Task added.")

def remove_task():
    task = input("Enter task to remove: ")

    if task in tasks:
        tasks.remove(task)
        print("Task removed.")
    else:
        print("Task not found.")

def view_tasks():
    if len(tasks) == 0:
        print("No tasks.")

    else:
        print("Your Tasks:")
        for task in tasks:
            print(task)


while True:

    print("\n1. Add Task")
    print("2. Remove Task")
    print("3. View Tasks")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_task()

    elif choice == "2":
        remove_task()

    elif choice == "3":
        view_tasks()

    elif choice == "4":
        print("Goodbye!")
        break

    else:
        print("Invalid choice.")
# Out:
# 1. Add Task
# 2. Remove Task
# 3. View Tasks
# 4. Exit
# Enter your choice: 22
# Invalid choice.
#
# 1. Add Task
# 2. Remove Task
# 3. View Tasks
# 4. Exit
# Enter your choice: 4
# Goodbye!

# %%
try:
  num1 = int(input("Enter a number: "))
  num2 = int(input("Enter another number: "))

  result = num1/num2

  print("Result:", result)

except ZeroDivisionError:
  print("Error! cannot divide by zero")

except ValueError:
  print("Error! enter a valid number")
# Out:
# Enter a number: 22
# Enter another number: 11
# Result: 2.0

# %%
class student:

  def __init__(self, name, marks):
    self.name=name
    self.marks=marks
  def grade(self):
    if self.marks >=80:
      return "A+"
    elif self.marks >=70:
      return "A"
    elif self.marks >=60:
      return "B"
    elif self.marks >=50:
      return "C"
    else:
      return "F"

name=input("Enter student name: ")
marks=int(input("Enter student marks: "))

student= student (name, marks)

print("Name:", student.name)
print("Marks:", student.marks)
print("grade:", student.grade())
try:
  num1 = int(input("Enter a number: "))
  num2 = int(input("Enter another number: "))

  result = num1/num2

  print("Result:", result)

except ZeroDivisionError:
  print("Error! cannot divide by zero")

except ValueError:
  print("Error! enter a valid number")
# Out:
# Enter student name: momina
# Enter student marks: 22
# Name: momina
# Marks: 22
# grade: None
# Enter a number: 11
# Enter another number: 33
# Result: 0.3333333333333333
